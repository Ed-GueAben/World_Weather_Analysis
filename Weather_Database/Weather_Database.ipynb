# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config_weather import weather_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 56.79,
#   'feels_like': 55.92,
#   'temp_min': 54.18,
#   'temp_max': 60.6,
#   'pressure': 1017,
#   'humidity': 80},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 110, 'gust': 10},
#  'clouds': {'all': 97},
#  'dt': 1654045280,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1653988242,
#   'sunset': 1654042411},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | zapolyarnyy
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | ulladulla
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | wolfhagen
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | olinda
# Processing Record 12 of Set 1 | dharchula
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | bereznik
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | akyab
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | taltal
# Processing Record 20 of Set 1 | sao filipe
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | smithers
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | laguna
# Processing Record 27 of Set 1 | pacific grove
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | pinheiro machado
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | ponta delgada
# Processing Record 35 of Set 1 | calama
# Processing Record 36 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | izhma
# Processing Record 42 of Set 1 | saint george
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | abbeville
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | belyy yar
# Processing Record 47 of Set 1 | rio grande
# Processing Record 48 of Set 1 | sitka
# Processing Record 49 of Set 1 | marau
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | opuwo
# Processing Record 2 of Set 2 | kehl
# Processing Record 3 of Set 2 | new richmond
# Processing Record 4 of Set 2 | teguise
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | ankazobe
# Processing Record 11 of Set 2 | russell
# Processing Record 12 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 2 | les cayes
# Processing Record 15 of Set 2 | guanare
# Processing Record 16 of Set 2 | olafsvik
# Processing Record 17 of Set 2 | ambon
# Processing Record 18 of Set 2 | melilla
# Processing Record 19 of Set 2 | tingo maria
# Processing Record 20 of Set 2 | antofagasta
# Processing Record 21 of Set 2 | leshukonskoye
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | mola di bari
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | klaksvik
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | ruwi
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | mumford
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | nisia floresta
# Processing Record 38 of Set 2 | kurchum
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | puerto madryn
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | kalasin
# Processing Record 48 of Set 2 | manavalakurichi
# Processing Record 49 of Set 2 | vanavara
# Processing Record 50 of Set 2 | manggar
# Processing Record 1 of Set 3 | larimna
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | calabozo
# Processing Record 4 of Set 3 | moron
# Processing Record 5 of Set 3 | beyneu
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | bluffton
# Processing Record 8 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 3 | limbang
# Processing Record 10 of Set 3 | cairns
# Processing Record 11 of Set 3 | darien
# Processing Record 12 of Set 3 | port blair
# Processing Record 13 of Set 3 | vao
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | redmond
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | fort nelson
# Processing Record 20 of Set 3 | kavaratti
# Processing Record 21 of Set 3 | eydhafushi
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | sogdiondon
# City not found. Skipping...
# Processing Record 27 of Set 3 | khash
# Processing Record 28 of Set 3 | walvis bay
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | mazagao
# Processing Record 31 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | kuching
# Processing Record 35 of Set 3 | sinjai
# Processing Record 36 of Set 3 | mwanza
# Processing Record 37 of Set 3 | imbituba
# Processing Record 38 of Set 3 | vardo
# Processing Record 39 of Set 3 | knysna
# Processing Record 40 of Set 3 | busia
# Processing Record 41 of Set 3 | zaragoza
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | vaini
# Processing Record 44 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 3 | iquique
# Processing Record 46 of Set 3 | cuapiaxtla
# Processing Record 47 of Set 3 | kirakira
# Processing Record 48 of Set 3 | falciu
# Processing Record 49 of Set 3 | mapastepec
# Processing Record 50 of Set 3 | liminangcong
# City not found. Skipping...
# Processing Record 1 of Set 4 | muli
# Processing Record 2 of Set 4 | cervo
# Processing Record 3 of Set 4 | canutama
# Processing Record 4 of Set 4 | gurh
# Processing Record 5 of Set 4 | beira
# Processing Record 6 of Set 4 | minna
# Processing Record 7 of Set 4 | provost
# Processing Record 8 of Set 4 | hope
# Processing Record 9 of Set 4 | korocha
# Processing Record 10 of Set 4 | booue
# Processing Record 11 of Set 4 | rabo de peixe
# Processing Record 12 of Set 4 | xichang
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | la crosse
# Processing Record 15 of Set 4 | kibuye
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 18 of Set 4 | avera
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | rincon
# Processing Record 23 of Set 4 | ahipara
# Processing Record 24 of Set 4 | micheweni
# Processing Record 25 of Set 4 | alice springs
# Processing Record 26 of Set 4 | hualmay
# Processing Record 27 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | nanhai
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | kutum
# Processing Record 32 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 4 | terra santa
# Processing Record 34 of Set 4 | louis trichardt
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | aleksandrov gay
# Processing Record 37 of Set 4 | beringovskiy
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | chumikan
# Processing Record 42 of Set 4 | brookhaven
# Processing Record 43 of Set 4 | srednekolymsk
# Processing Record 44 of Set 4 | ghugus
# Processing Record 45 of Set 4 | bellefontaine
# Processing Record 46 of Set 4 | maniitsoq
# Processing Record 47 of Set 4 | berlevag
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | vyshneve
# Processing Record 1 of Set 5 | sorong
# Processing Record 2 of Set 5 | san quintin
# Processing Record 3 of Set 5 | pitimbu
# Processing Record 4 of Set 5 | honiara
# Processing Record 5 of Set 5 | lhokseumawe
# Processing Record 6 of Set 5 | tautira
# Processing Record 7 of Set 5 | mar del plata
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | ormara
# Processing Record 11 of Set 5 | alta floresta
# Processing Record 12 of Set 5 | saint-augustin
# Processing Record 13 of Set 5 | san andres
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | kikwit
# Processing Record 16 of Set 5 | aiquile
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | fomboni
# Processing Record 19 of Set 5 | tuktoyaktuk
# Processing Record 20 of Set 5 | havelock
# Processing Record 21 of Set 5 | the valley
# Processing Record 22 of Set 5 | derzhavinsk
# Processing Record 23 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 5 | odweyne
# Processing Record 25 of Set 5 | macedo de cavaleiros
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | palmer
# Processing Record 28 of Set 5 | saint-pierre
# Processing Record 29 of Set 5 | rexburg
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | nanakuli
# Processing Record 32 of Set 5 | dunedin
# Processing Record 33 of Set 5 | canandaigua
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | praya
# Processing Record 36 of Set 5 | tabou
# Processing Record 37 of Set 5 | kaitangata
# Processing Record 38 of Set 5 | mount gambier
# Processing Record 39 of Set 5 | poum
# Processing Record 40 of Set 5 | isiro
# Processing Record 41 of Set 5 | ariquemes
# Processing Record 42 of Set 5 | nizhniy lomov
# Processing Record 43 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 5 | zwedru
# Processing Record 47 of Set 5 | kurtalan
# Processing Record 48 of Set 5 | price
# Processing Record 49 of Set 5 | tambovka
# Processing Record 50 of Set 5 | banjar
# Processing Record 1 of Set 6 | nouadhibou
# Processing Record 2 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 6 | esperance
# Processing Record 4 of Set 6 | fez
# Processing Record 5 of Set 6 | makokou
# Processing Record 6 of Set 6 | zachary
# Processing Record 7 of Set 6 | hundorp
# Processing Record 8 of Set 6 | tepango
# Processing Record 9 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 10 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | axim
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | eyl
# Processing Record 15 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 6 | evanston
# Processing Record 17 of Set 6 | marienburg
# Processing Record 18 of Set 6 | lima
# Processing Record 19 of Set 6 | anadyr
# Processing Record 20 of Set 6 | mlonggo
# Processing Record 21 of Set 6 | coquimbo
# Processing Record 22 of Set 6 | siniscola
# Processing Record 23 of Set 6 | beloha
# Processing Record 24 of Set 6 | kaili
# Processing Record 25 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 6 | komsomolskiy
# Processing Record 27 of Set 6 | sinegorye
# Processing Record 28 of Set 6 | thinadhoo
# Processing Record 29 of Set 6 | castro
# Processing Record 30 of Set 6 | kidal
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | otradnoye
# Processing Record 33 of Set 6 | la tuque
# Processing Record 34 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | sabirabad
# Processing Record 36 of Set 6 | mujiayingzi
# Processing Record 37 of Set 6 | moose factory
# Processing Record 38 of Set 6 | dingle
# Processing Record 39 of Set 6 | northam
# Processing Record 40 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 42 of Set 6 | iralaya
# Processing Record 43 of Set 6 | irondequoit
# Processing Record 44 of Set 6 | chicama
# Processing Record 45 of Set 6 | kruisfontein
# Processing Record 46 of Set 6 | martapura
# Processing Record 47 of Set 6 | eureka
# Processing Record 48 of Set 6 | dryden
# Processing Record 49 of Set 6 | sept-iles
# Processing Record 50 of Set 6 | ikovka
# Processing Record 1 of Set 7 | egvekinot
# Processing Record 2 of Set 7 | iqaluit
# Processing Record 3 of Set 7 | stamford
# Processing Record 4 of Set 7 | marsh harbour
# Processing Record 5 of Set 7 | arlit
# Processing Record 6 of Set 7 | cloquet
# Processing Record 7 of Set 7 | upernavik
# Processing Record 8 of Set 7 | souillac
# Processing Record 9 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 7 | svetlyy
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | trofors
# Processing Record 13 of Set 7 | letlhakane
# Processing Record 14 of Set 7 | atar
# Processing Record 15 of Set 7 | te anau
# Processing Record 16 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 7 | portland
# Processing Record 18 of Set 7 | macamic
# Processing Record 19 of Set 7 | hvide sande
# Processing Record 20 of Set 7 | vredendal
# Processing Record 21 of Set 7 | ribeira grande
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | cayenne
# Processing Record 24 of Set 7 | siguiri
# Processing Record 25 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | vorontsovka
# Processing Record 29 of Set 7 | milan
# Processing Record 30 of Set 7 | aginskoye
# Processing Record 31 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 7 | teya
# Processing Record 33 of Set 7 | balkanabat
# Processing Record 34 of Set 7 | channel-port aux basques
# Processing Record 35 of Set 7 | victoria
# Processing Record 36 of Set 7 | aykhal
# Processing Record 37 of Set 7 | hauterive
# Processing Record 38 of Set 7 | kanniyakumari
# Processing Record 39 of Set 7 | vila velha
# Processing Record 40 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 7 | lagoa
# Processing Record 42 of Set 7 | sturgeon falls
# Processing Record 43 of Set 7 | metu
# Processing Record 44 of Set 7 | kendari
# Processing Record 45 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 7 | acapulco
# Processing Record 47 of Set 7 | manokwari
# Processing Record 48 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 7 | berdigestyakh
# Processing Record 50 of Set 7 | praia da vitoria
# Processing Record 1 of Set 8 | hlatikulu
# Processing Record 2 of Set 8 | lakheri
# Processing Record 3 of Set 8 | itarema
# Processing Record 4 of Set 8 | bengkulu
# Processing Record 5 of Set 8 | piacabucu
# Processing Record 6 of Set 8 | ruteng
# Processing Record 7 of Set 8 | bosaso
# Processing Record 8 of Set 8 | bambous virieux
# Processing Record 9 of Set 8 | manzanillo
# Processing Record 10 of Set 8 | chuy
# Processing Record 11 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 8 | dicabisagan
# Processing Record 13 of Set 8 | bima
# Processing Record 14 of Set 8 | dzhebariki-khaya
# Processing Record 15 of Set 8 | mercedes
# Processing Record 16 of Set 8 | adjumani
# Processing Record 17 of Set 8 | sooke
# Processing Record 18 of Set 8 | jennings
# Processing Record 19 of Set 8 | kushiro
# Processing Record 20 of Set 8 | saint petersburg
# Processing Record 21 of Set 8 | biak
# Processing Record 22 of Set 8 | shizunai
# Processing Record 23 of Set 8 | were ilu
# Processing Record 24 of Set 8 | sri aman
# Processing Record 25 of Set 8 | listvyanka
# Processing Record 26 of Set 8 | nashville
# Processing Record 27 of Set 8 | chapais
# Processing Record 28 of Set 8 | alvaraes
# Processing Record 29 of Set 8 | itaqui
# Processing Record 30 of Set 8 | dunmore town
# Processing Record 31 of Set 8 | raudeberg
# Processing Record 32 of Set 8 | xinzhou
# Processing Record 33 of Set 8 | karpathos
# Processing Record 34 of Set 8 | bom jesus
# Processing Record 35 of Set 8 | paamiut
# Processing Record 36 of Set 8 | togur
# Processing Record 37 of Set 8 | romanovskaya
# Processing Record 38 of Set 8 | nizwa
# Processing Record 39 of Set 8 | port maria
# Processing Record 40 of Set 8 | batagay-alyta
# Processing Record 41 of Set 8 | meadow lake
# Processing Record 42 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 43 of Set 8 | puerto cabello
# Processing Record 44 of Set 8 | estelle
# Processing Record 45 of Set 8 | kosai
# Processing Record 46 of Set 8 | vidim
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 8 | kavieng
# Processing Record 50 of Set 8 | bobcaygeon
# Processing Record 1 of Set 9 | yerbogachen
# Processing Record 2 of Set 9 | oranjemund
# Processing Record 3 of Set 9 | salinas
# Processing Record 4 of Set 9 | pires do rio
# Processing Record 5 of Set 9 | lugovoy
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | cariamanga
# Processing Record 8 of Set 9 | roma
# Processing Record 9 of Set 9 | tuatapere
# Processing Record 10 of Set 9 | lucapa
# Processing Record 11 of Set 9 | simao
# Processing Record 12 of Set 9 | bady bassitt
# Processing Record 13 of Set 9 | ho
# City not found. Skipping...
# Processing Record 14 of Set 9 | isla vista
# Processing Record 15 of Set 9 | san luis
# Processing Record 16 of Set 9 | hambantota
# Processing Record 17 of Set 9 | mecca
# Processing Record 18 of Set 9 | hingoli
# Processing Record 19 of Set 9 | yatou
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | boddam
# Processing Record 22 of Set 9 | galesburg
# Processing Record 23 of Set 9 | dali
# Processing Record 24 of Set 9 | brae
# Processing Record 25 of Set 9 | kilindoni
# Processing Record 26 of Set 9 | iaciara
# Processing Record 27 of Set 9 | juneau
# Processing Record 28 of Set 9 | port macquarie
# Processing Record 29 of Set 9 | harper
# Processing Record 30 of Set 9 | maamba
# Processing Record 31 of Set 9 | dickinson
# Processing Record 32 of Set 9 | buchanan
# Processing Record 33 of Set 9 | ola
# Processing Record 34 of Set 9 | bahia blanca
# Processing Record 35 of Set 9 | fenton
# Processing Record 36 of Set 9 | daru
# Processing Record 37 of Set 9 | liberty
# Processing Record 38 of Set 9 | vastervik
# City not found. Skipping...
# Processing Record 39 of Set 9 | vila do maio
# Processing Record 40 of Set 9 | noumea
# Processing Record 41 of Set 9 | port-gentil
# Processing Record 42 of Set 9 | odesskoye
# Processing Record 43 of Set 9 | andros town
# Processing Record 44 of Set 9 | neiafu
# Processing Record 45 of Set 9 | sur
# Processing Record 46 of Set 9 | korla
# Processing Record 47 of Set 9 | sioux lookout
# Processing Record 48 of Set 9 | baherden
# Processing Record 49 of Set 9 | pedernales
# Processing Record 50 of Set 9 | yakeshi
# Processing Record 1 of Set 10 | alexandria
# Processing Record 2 of Set 10 | germantown
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | kentau
# Processing Record 5 of Set 10 | kahului
# Processing Record 6 of Set 10 | iberia
# Processing Record 7 of Set 10 | bud
# Processing Record 8 of Set 10 | merauke
# Processing Record 9 of Set 10 | assiniboia
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 10 | lishui
# Processing Record 13 of Set 10 | nadbai
# Processing Record 14 of Set 10 | lufkin
# Processing Record 15 of Set 10 | chikwawa
# Processing Record 16 of Set 10 | el dorado
# Processing Record 17 of Set 10 | kolvereid
# Processing Record 18 of Set 10 | bestobe
# Processing Record 19 of Set 10 | sencha
# Processing Record 20 of Set 10 | dwarka
# Processing Record 21 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 10 | fairbanks
# Processing Record 23 of Set 10 | mikhaylovsk
# Processing Record 24 of Set 10 | samana
# Processing Record 25 of Set 10 | roebourne
# Processing Record 26 of Set 10 | ismailia
# Processing Record 27 of Set 10 | santiago de cao
# Processing Record 28 of Set 10 | guarare
# Processing Record 29 of Set 10 | tommot
# Processing Record 30 of Set 10 | caceres
# Processing Record 31 of Set 10 | nijar
# Processing Record 32 of Set 10 | worland
# Processing Record 33 of Set 10 | huarmey
# Processing Record 34 of Set 10 | quatre cocos
# Processing Record 35 of Set 10 | san pedro
# Processing Record 36 of Set 10 | ossora
# Processing Record 37 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 38 of Set 10 | devonport
# Processing Record 39 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 10 | boyolangu
# Processing Record 41 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 10 | honningsvag
# Processing Record 43 of Set 10 | inta
# Processing Record 44 of Set 10 | rio gallegos
# Processing Record 45 of Set 10 | tatawin
# Processing Record 46 of Set 10 | namatanai
# Processing Record 47 of Set 10 | constitucion
# Processing Record 48 of Set 10 | marsa matruh
# Processing Record 49 of Set 10 | ngorongoro
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | etchoropo
# Processing Record 2 of Set 11 | chokurdakh
# Processing Record 3 of Set 11 | baruun-urt
# Processing Record 4 of Set 11 | mishan
# Processing Record 5 of Set 11 | vestmanna
# Processing Record 6 of Set 11 | lethem
# Processing Record 7 of Set 11 | mamakan
# Processing Record 8 of Set 11 | vila franca do campo
# Processing Record 9 of Set 11 | banda aceh
# Processing Record 10 of Set 11 | tiznit
# Processing Record 11 of Set 11 | namibe
# Processing Record 12 of Set 11 | auki
# Processing Record 13 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 11 | almeria
# Processing Record 15 of Set 11 | weligama
# Processing Record 16 of Set 11 | rameswaram
# Processing Record 17 of Set 11 | bijie
# Processing Record 18 of Set 11 | mayskiy
# Processing Record 19 of Set 11 | genhe
# Processing Record 20 of Set 11 | yanam
# Processing Record 21 of Set 11 | richards bay
# Processing Record 22 of Set 11 | necochea
# Processing Record 23 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 11 | saint-georges
# Processing Record 25 of Set 11 | schijndel
# Processing Record 26 of Set 11 | dukat
# Processing Record 27 of Set 11 | sungaipenuh
# Processing Record 28 of Set 11 | misratah
# Processing Record 29 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 30 of Set 11 | iglesias
# Processing Record 31 of Set 11 | kununurra
# Processing Record 32 of Set 11 | havre-saint-pierre
# Processing Record 33 of Set 11 | visegrad
# Processing Record 34 of Set 11 | citta di castello
# Processing Record 35 of Set 11 | autopan
# City not found. Skipping...
# Processing Record 36 of Set 11 | mapiripan
# Processing Record 37 of Set 11 | gorontalo
# Processing Record 38 of Set 11 | aksarka
# Processing Record 39 of Set 11 | khandbari
# Processing Record 40 of Set 11 | puerto del rosario
# Processing Record 41 of Set 11 | jacksonville
# Processing Record 42 of Set 11 | am timan
# Processing Record 43 of Set 11 | aitape
# Processing Record 44 of Set 11 | santiago
# Processing Record 45 of Set 11 | sumagui
# Processing Record 46 of Set 11 | katherine
# Processing Record 47 of Set 11 | singaraja
# Processing Record 48 of Set 11 | benghazi
# Processing Record 49 of Set 11 | svetlaya
# Processing Record 50 of Set 11 | pochutla
# Processing Record 1 of Set 12 | santa vitoria do palmar
# Processing Record 2 of Set 12 | kadoma
# Processing Record 3 of Set 12 | kaeo
# Processing Record 4 of Set 12 | kamenka
# Processing Record 5 of Set 12 | muroran
# Processing Record 6 of Set 12 | abay
# Processing Record 7 of Set 12 | istria
# Processing Record 8 of Set 12 | cam ranh
# Processing Record 9 of Set 12 | alekseyevsk
# Processing Record 10 of Set 12 | henties bay
# Processing Record 11 of Set 12 | nome
# Processing Record 12 of Set 12 | ko samui
# Processing Record 13 of Set 12 | huaidian
# Processing Record 14 of Set 12 | roald
# Processing Record 15 of Set 12 | umm lajj
# Processing Record 16 of Set 12 | geraldton
# Processing Record 17 of Set 12 | lumphat
# Processing Record 18 of Set 12 | buluang
# Processing Record 19 of Set 12 | darhan
# Processing Record 20 of Set 12 | valparaiso
# Processing Record 21 of Set 12 | scarborough
# Processing Record 22 of Set 12 | surt
# Processing Record 23 of Set 12 | mayor pablo lagerenza
# Processing Record 24 of Set 12 | bongandanga
# Processing Record 25 of Set 12 | tocopilla
# Processing Record 26 of Set 12 | caravelas
# Processing Record 27 of Set 12 | youghal
# Processing Record 28 of Set 12 | aklavik
# Processing Record 29 of Set 12 | coruripe
# Processing Record 30 of Set 12 | inuvik
# Processing Record 31 of Set 12 | kamaishi
# Processing Record 32 of Set 12 | taoudenni
# Processing Record 33 of Set 12 | salekhard
# Processing Record 34 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 12 | port augusta
# Processing Record 36 of Set 12 | badhni kalan
# Processing Record 37 of Set 12 | harrisonville
# Processing Record 38 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 12 | kuytun
# Processing Record 40 of Set 12 | chippewa falls
# Processing Record 41 of Set 12 | lasa
# Processing Record 42 of Set 12 | jha jha
# Processing Record 43 of Set 12 | panguna
# Processing Record 44 of Set 12 | juarez
# Processing Record 45 of Set 12 | kodinar
# Processing Record 46 of Set 12 | polyarnyy
# Processing Record 47 of Set 12 | orange walk
# Processing Record 48 of Set 12 | pamanukan
# Processing Record 49 of Set 12 | mayumba
# Processing Record 50 of Set 12 | voh
# Processing Record 1 of Set 13 | flagstaff
# Processing Record 2 of Set 13 | lorengau
# Processing Record 3 of Set 13 | ayorou
# Processing Record 4 of Set 13 | tornio
# Processing Record 5 of Set 13 | nhulunbuy
# Processing Record 6 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 8 of Set 13 | asau
# Processing Record 9 of Set 13 | praia
# Processing Record 10 of Set 13 | montanha
# Processing Record 11 of Set 13 | phalodi
# Processing Record 12 of Set 13 | sardarshahr
# Processing Record 13 of Set 13 | vrangel
# Processing Record 14 of Set 13 | tateyama
# Processing Record 15 of Set 13 | bathsheba
# Processing Record 16 of Set 13 | trinidad
# Processing Record 17 of Set 13 | coihaique
# Processing Record 18 of Set 13 | waconia
# Processing Record 19 of Set 13 | mareeba
# Processing Record 20 of Set 13 | gamba
# Processing Record 21 of Set 13 | sorland
# Processing Record 22 of Set 13 | gold coast
# Processing Record 23 of Set 13 | russkiy kameshkir
# Processing Record 24 of Set 13 | mogok
# Processing Record 25 of Set 13 | thompson
# Processing Record 26 of Set 13 | hami
# Processing Record 27 of Set 13 | mangochi
# Processing Record 28 of Set 13 | moyuta
# Processing Record 29 of Set 13 | neyshabur
# Processing Record 30 of Set 13 | uusikaupunki
# Processing Record 31 of Set 13 | liverpool
# Processing Record 32 of Set 13 | tabuk
# Processing Record 33 of Set 13 | kropotkin
# Processing Record 34 of Set 13 | damghan
# Processing Record 35 of Set 13 | chapada dos guimaraes
# Processing Record 36 of Set 13 | tual
# Processing Record 37 of Set 13 | margate
# Processing Record 38 of Set 13 | phan thiet
# Processing Record 39 of Set 13 | westport
# Processing Record 40 of Set 13 | saint-hyacinthe
# Processing Record 41 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 13 | zlobin
# Processing Record 43 of Set 13 | sao joao da barra
# Processing Record 44 of Set 13 | guilin
# Processing Record 45 of Set 13 | charters towers
# Processing Record 46 of Set 13 | cururupu
# Processing Record 47 of Set 13 | new port richey
# Processing Record 48 of Set 13 | umm kaddadah
# Processing Record 49 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 50 of Set 13 | deputatskiy
# Processing Record 1 of Set 14 | luganville
# Processing Record 2 of Set 14 | vinh
# Processing Record 3 of Set 14 | luwingu
# Processing Record 4 of Set 14 | tuysarkan
# City not found. Skipping...
# Processing Record 5 of Set 14 | nabisar
# Processing Record 6 of Set 14 | goderich
# Processing Record 7 of Set 14 | betare oya
# Processing Record 8 of Set 14 | jaru
# Processing Record 9 of Set 14 | ankpa
# Processing Record 10 of Set 14 | charcas
# Processing Record 11 of Set 14 | adwa
# Processing Record 12 of Set 14 | ugoofaaru
# Processing Record 13 of Set 14 | zarand
# Processing Record 14 of Set 14 | panama city
# Processing Record 15 of Set 14 | poquoson
# Processing Record 16 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 14 | amazar
# Processing Record 18 of Set 14 | pontian kecil
# Processing Record 19 of Set 14 | puerto escondido
# Processing Record 20 of Set 14 | nishihara
# Processing Record 21 of Set 14 | jaguarao
# Processing Record 22 of Set 14 | goure
# Processing Record 23 of Set 14 | bundaberg
# Processing Record 24 of Set 14 | okhotsk
# Processing Record 25 of Set 14 | tongzi
# Processing Record 26 of Set 14 | sadowara
# City not found. Skipping...
# Processing Record 27 of Set 14 | latur
# Processing Record 28 of Set 14 | maungatapere
# Processing Record 29 of Set 14 | ust-nera
# Processing Record 30 of Set 14 | hofn
# Processing Record 31 of Set 14 | labuhan
# Processing Record 32 of Set 14 | ciudad bolivar
# Processing Record 33 of Set 14 | meulaboh
# Processing Record 34 of Set 14 | hirara
# Processing Record 35 of Set 14 | yichang
# Processing Record 36 of Set 14 | paithan
# Processing Record 37 of Set 14 | yar-sale
# Processing Record 38 of Set 14 | svetlyy yar
# Processing Record 39 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 14 | benemerito de las americas
# Processing Record 41 of Set 14 | naze
# Processing Record 42 of Set 14 | batemans bay
# Processing Record 43 of Set 14 | riyadh
# Processing Record 44 of Set 14 | sokoni
# Processing Record 45 of Set 14 | nemuro
# Processing Record 46 of Set 14 | izvestkovyy
# Processing Record 47 of Set 14 | sabang
# Processing Record 48 of Set 14 | gazli
# Processing Record 49 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 14 | semnan
# Processing Record 1 of Set 15 | bemidji
# Processing Record 2 of Set 15 | dauriya
# Processing Record 3 of Set 15 | marzuq
# Processing Record 4 of Set 15 | huron
# Processing Record 5 of Set 15 | carutapera
# Processing Record 6 of Set 15 | eufaula
# Processing Record 7 of Set 15 | seydi
# Processing Record 8 of Set 15 | kloulklubed
# Processing Record 9 of Set 15 | tiarei
# Processing Record 10 of Set 15 | straumen
# Processing Record 11 of Set 15 | langsa
# Processing Record 12 of Set 15 | thalheim
# Processing Record 13 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 14 of Set 15 | chodziez
# Processing Record 15 of Set 15 | tanabe
# Processing Record 16 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 15 | hervey bay
# Processing Record 18 of Set 15 | gurkovo
# Processing Record 19 of Set 15 | litovko
# Processing Record 20 of Set 15 | fallon
# Processing Record 21 of Set 15 | carauari
# Processing Record 22 of Set 15 | tutoia
# Processing Record 23 of Set 15 | caucaia
# Processing Record 24 of Set 15 | el alto
# Processing Record 25 of Set 15 | porto novo
# Processing Record 26 of Set 15 | omsukchan
# Processing Record 27 of Set 15 | biltine
# Processing Record 28 of Set 15 | ca mau
# Processing Record 29 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 15 | pyshchug
# Processing Record 31 of Set 15 | uglich
# Processing Record 32 of Set 15 | tura
# Processing Record 33 of Set 15 | yaan
# Processing Record 34 of Set 15 | panorama
# Processing Record 35 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 15 | broome
# Processing Record 38 of Set 15 | severnoye
# Processing Record 39 of Set 15 | iracoubo
# Processing Record 40 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 41 of Set 15 | karratha
# Processing Record 42 of Set 15 | mopti
# Processing Record 43 of Set 15 | buraydah
# Processing Record 44 of Set 15 | coahuayana
# Processing Record 45 of Set 15 | ust-kuyga
# Processing Record 46 of Set 15 | ilebo
# Processing Record 47 of Set 15 | grand-santi
# Processing Record 48 of Set 15 | caohe
# Processing Record 49 of Set 15 | gorin
# Processing Record 50 of Set 15 | ostrovnoy
# Processing Record 1 of Set 16 | surazh
# Processing Record 2 of Set 16 | lerwick
# Processing Record 3 of Set 16 | kralendijk
# Processing Record 4 of Set 16 | archidona
# Processing Record 5 of Set 16 | warrnambool
# Processing Record 6 of Set 16 | lillooet
# Processing Record 7 of Set 16 | half moon bay
# Processing Record 8 of Set 16 | celestun
# Processing Record 9 of Set 16 | copiapo
# Processing Record 10 of Set 16 | berdyuzhye
# City not found. Skipping...
# Processing Record 11 of Set 16 | baboua
# City not found. Skipping...
# Processing Record 12 of Set 16 | upata
# Processing Record 13 of Set 16 | marawi
# Processing Record 14 of Set 16 | villa carlos paz
# Processing Record 15 of Set 16 | payyannur
# Processing Record 16 of Set 16 | lampazos de naranjo
# Processing Record 17 of Set 16 | shingu
# Processing Record 18 of Set 16 | tecoanapa
# Processing Record 19 of Set 16 | puerto colombia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0     Cidreira -30.1811  -50.2056     48.33           clear sky        77
# 1  Zapolyarnyy  69.4154   30.8136     36.68           clear sky        79
# 2       Atuona  -9.8000 -139.0333     78.17           clear sky        72
# 3   Butaritari   3.0707  172.7902     81.50           clear sky        77
# 4    Ulladulla -35.3500  150.4667     52.70       broken clouds        52
# 5     Katsuura  35.1333  140.3000     70.74     overcast clouds        69
# 6    Wolfhagen  51.3261    9.1702     48.42          light rain        88
# 7     Tasiilaq  65.6145  -37.6368     37.56     overcast clouds        94
# 8    Busselton -33.6500  115.3333     54.93     overcast clouds        71
# 9    Carnarvon -24.8667  113.6333     59.23           clear sky        68
#
#    Cloudiness  Wind Speed Country
# 0           7        4.34      BR
# 1           2        4.72      RU
# 2          10       11.97      PF
# 3           5       10.96      KI
# 4          61       19.98      AU
# 5         100       11.16      JP
# 6          76        3.33      DE
# 7         100        2.55      GL
# 8         100        5.41      AU
# 9           0       18.03      AU

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df [new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cidreira      BR -30.1811  -50.2056     48.33        77           7
# 1  Zapolyarnyy      RU  69.4154   30.8136     36.68        79           2
# 2       Atuona      PF  -9.8000 -139.0333     78.17        72          10
# 3   Butaritari      KI   3.0707  172.7902     81.50        77           5
# 4    Ulladulla      AU -35.3500  150.4667     52.70        52          61
# 5     Katsuura      JP  35.1333  140.3000     70.74        69         100
# 6    Wolfhagen      DE  51.3261    9.1702     48.42        88          76
# 7     Tasiilaq      GL  65.6145  -37.6368     37.56        94         100
# 8    Busselton      AU -33.6500  115.3333     54.93        71         100
# 9    Carnarvon      AU -24.8667  113.6333     59.23        68           0
#
#    Wind Speed Current Description
# 0        4.34           clear sky
# 1        4.72           clear sky
# 2       11.97           clear sky
# 3       10.96           clear sky
# 4       19.98       broken clouds
# 5       11.16     overcast clouds
# 6        3.33          light rain
# 7        2.55     overcast clouds
# 8        5.41     overcast clouds
# 9       18.03           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
